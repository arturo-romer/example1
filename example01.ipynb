# %% [markdown]
# <a href="https://colab.research.google.com/github/arturo-romer/example1/blob/main/example01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 3 + 5
print(num)
# Out:
# 8

# %%
num
# Out:
# 8
